# %% [markdown]
# # Analyzing an Actin Coding Sequence

# %% [markdown]
# ## Introduction
#
# Given the following DNA coding sequence for actin (CDS, so no introns), let's use your new Python skills to answer some basic biology questions.

# %%
actin = "..."

# %% [markdown]
# ## Questions
#
# Complete each of the questions below in the code cell that follows it.

# %% [markdown]
# ### Q1. How long is the total sequence?
#
# > Hint: `len()`

# %% [markdown]
# ### Q2. How many tryptophans are there (codon TGG)?
#
# > Hint: `.count()`

# %% [markdown]
# ### Q3. Can you figure out what the GC content is?

# %% [markdown]
# ### Q4. Where is the beginning of the coding sequence (start codon ATG)?
#
# > Hint: `.find()`

# %% [markdown]
# ### Q5: Given that the stop codon is either TAA, TAG, or TGA, can you figure out how many amino acids are encoded by this sequence?
