# %% [markdown]
# # The Basics of Python
#
# ## Introduction
#
# Welcome to your first Python coding session! Python is a powerful, beginner-friendly programming language widely used in biological research for data analysis, sequence manipulation, and statistical modeling. In this notebook, we will work through four exercises together—type the code into each cell as we go, and run it to see the results.

# %% [markdown]
# ## Exercise 1: Arithmetic Operations
#
# Python can be used as a calculator. Let's explore the basic math operators: addition (`+`), subtraction (`-`), multiplication (`*`), division (`/`), modulo (`%`), and exponentiation (`**`).
#
# Try each operation one at a time:
#
# - 5 + 3
# - 10 - 4
# - 12 * 4
# - 20 / 6

# %% [markdown]
# Now try the modulo operator to return the remainder after division and the exponentiation operator to raise a number to a power.
#
# - 20 % 6
# - 2 ** 3

# %% [markdown]
# ## Exercise 2: Calculate Cell Growth Over Time
#
# Let's apply Python to a biology problem! We'll calculate how many cells we have after a certain time period, given a starting count and doubling time.
#
# First, define our variables:

# %%
cells = 1000
doubling_time = 24
time_elapsed = 72
goal = 5000

# %% [markdown]
# Now, calculate cell growth and check if we've reached our threshold:

# %%
# Define a new variable `doublings` equal to the time elapsed divided by the doubling time


# Update the value of `cells` to be equal to cells multiplied by `2 ** doublings`


ready = cells > goal

print("Succeed?", ready)
print("Difference:", cells - goal)

# %% [markdown]
# Challenge questions:
#
# - How would you modify the code to get to 50,000 cells?
# - What is the type() of cells? doublings? ready?

# %% [markdown]
# ## Exercise 3: Parse a DNA Sequence
#
# Strings are a natural way to work with biological sequences. The `print()` function can combine multiple strings, using the `sep` argument to specify a delimiter. We can also concatenate strings using `+` and use string methods like `.count()` and `.find()` to analyze them.
#
# Let's first create three codon strings:

# %%
a = "ATG"
b = "TGG"
c = "TAA"

# %% [markdown]
# Now print them with different separators using the sep argument:
#
# - Comma (`,`)
# - Tab (`\t`)
# - Nothing ()
#
# Use `help( print )` if you need a reminder

# %% [markdown]
# The `print()` function displays output but doesn't store it for later use. To create a combined sequence that we can operate on, create a new string using the `+` operator to concatenate the codons together.
#
# - Build a sequence `ATGTGGTGGTAA`
# - Count tryptophans (TGG) using `.count()`
# - Use `.find()` to locate the position of the stop codon (TAA)

# %% [markdown]
# ## Exercise 4: Convert Comma to Tab Delimited
#
# Bioinformatics often requires converting between file formats. The `.split()` method breaks a string into a list, and `.join()` combines a list back into a string with a separator.
#
# First, explore the documentation with `help( str.split )`

# %% [markdown]
# Now split a comma-separated string:

# %%
my_genes = "BRCA1,TP53,MYC"
my_list = 

# What does .split() return?  Hint: type()

# %% [markdown]
# Join a list back into a string:

# %%
" ".join( my_list )

# Convert to tab delimited ("\t")  Hint: help( str.join )
